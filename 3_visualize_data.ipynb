# %% [markdown]
# # Визуализация данных в Python

# %% [markdown]
# ## Обзор библиотек

# %% [markdown]
# 1. Matplotlib - базовая графика
# 2. Seaborn - углубленная базовая графика
# 3. Plotly - динамические графики

# %% [markdown]
# | Matplotlib | Seaborn |
# | ----------- | ----------- |
# | Используется для базового построения графиков, таких как линейные диаграммы, гистограммы и т. д.    | Используется для визуализации статистики и может выполнять сложные визуализации с меньшим количеством команд.   |
# |  Продуктивно работает с массивами данных и фреймами.  | Seaborn значительно более организован и функционален, чем Matplotlib, и рассматривает весь набор данных как единую единицу.   |
# | Matplotlib более настраиваемый и хорошо сочетается с Pandas и Numpy для анализа исследуемых данных.   | Seaborn имеет больше встроенных тем и в основном используется для статистического анализа.  |

# %% [markdown]
# ## Линейные графики

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Сгенерируем простой набор данных.

# %%
y = [1, 2, 3, 3.5, 3.7, 4, 4.1]

# %% [markdown]
# Визуализируем с помощью функции **plot**.

# %%
plt.plot(y)
plt.show()

# %% [markdown]
# Добавим ось ОХ.

# %%
x = [2017, 2018, 2019, 2020, 2021, 2022, 2023]

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# Добавляем подписи осей.

# %%
plt.plot(x,y)
plt.xlabel('Год')
plt.ylabel('Значения показателя')
plt.show()

# %% [markdown]
# Добавляем второй набор данных и отрисовываем оба ряда на одном графике.

# %%
#y = [1, 2, 3, 3.5, 3.7, 4, 4.1]
y2 = [6.8, 6.7, 6.5, 5, 5.1, 3.0, 2]
#x = [2017, 2018, 2019, 2020, 2021, 2022, 2023]
plt.plot(x,y)
plt.plot(x,y2)
plt.xlabel('Год')
plt.ylabel('Показатели')
plt.show()

# %% [markdown]
# Добавляем легенду.

# %%
plt.plot(x,y)
plt.plot(x,y2)
plt.xlabel('Год')
plt.ylabel('Показатели')
plt.title('Динамика показателя')
plt.legend(['y', 'y2'])
plt.show()

# %% [markdown]
# Добавляем маркеры для выделения каждого наблюдения.

# %%
plt.plot(x,y, marker = 'o')
plt.plot(x,y2, marker = 'x')
plt.xlabel('Год')
plt.ylabel('Показатели')
plt.title('Динамика показателя')
plt.legend(['y', 'y2'])
plt.show()

# %% [markdown]
# Построим все то же самое с помощью библиотеки **Seaborn**.

# %%
sns.set_style("whitegrid") #darkgrid

plt.plot(x,y, marker = 'o')
plt.plot(x,y2, marker = 'x')
plt.xlabel('Год')
plt.ylabel('Показатели')
plt.title('Динамика показателя')
plt.legend(['y', 'y2'])
plt.show()

# %% [markdown]
# ## Barplot или столбчатые графики

# %%
plt.bar(x,y)
plt.xlabel('Год')
plt.ylabel('Показатели')
plt.title('Динамика показателя')
plt.show()

# %%
plt.bar(x,y)
plt.bar(x,y2, bottom = y)
plt.show()

# %% [markdown]
# ## График-пирог

# %%
x_labels = ['2017', '2018', '2019', '2020', '2021', '2022', '2023']
plt.pie(y, labels = x_labels)
plt.show()

# %% [markdown]
# ## Гистограммы

# %%
iris = sns.load_dataset("iris")
plt.hist(iris.sepal_length)
plt.show()

# %% [markdown]
# Можем задать количество блоков с помощью параметра **bins**.

# %%
plt.hist(iris.sepal_length, bins = 30)
plt.show()

# %% [markdown]
# Регулируем прозрачность гистограммы с помощью параметра **alpha**. Можем построить гистограммы для нескольких наборов данных на одном графике.

# %%
plt.hist(iris.sepal_length, alpha = 0.4)
plt.hist(iris.petal_length, alpha = 0.4)
plt.show()

# %% [markdown]
# Параметр **stacked** для совместной отрисовки данных.

# %%
plt.hist([iris.sepal_length,iris.petal_length], stacked = True)
plt.show()

# %% [markdown]
# ## Точечные графики или scatteplot

# %%
ax = sns.scatterplot(x='petal_length', y='sepal_length', data=iris)
plt.show()

# %%
ax = sns.scatterplot(x="petal_length", y="sepal_length", data=iris, hue = 'species')
plt.show()

# %% [markdown]
# ## Тепловые карты

# %%
flights = sns.load_dataset("flights").pivot("month", "year", "passengers")
flights

#почему-то тепловые карты у меня не работают :(
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Валерия Савина\Downloads\3_visualize_data.ipynb Ячейка 41 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/%D0%92%D0%B0%D0%BB%D0%B5%D1%80%D0%B8%D1%8F%20%D0%A1%D0%B0%D0%B2%D0%B8%D0%BD%D0%B0/Downloads/3_visualize_data.ipynb#X55sZmlsZQ%3D%3D?line=0'>1</a> flights = sns.load_dataset("flights").pivot("month", "year", "passengers")
#       <a href='vscode-notebook-cell:/c%3A/Users/%D0%92%D0%B0%D0%BB%D0%B5%D1%80%D0%B8%D1%8F%20%D0%A1%D0%B0%D0%B2%D0%B8%D0%BD%D0%B0/Downloads/3_visualize_data.ipynb#X55sZmlsZQ%3D%3D?line=1'>2</a> flights
#
# TypeError: DataFrame.pivot() takes 1 positional argument but 4 were given

# %% [markdown]
# Приведенный выше набор данных *flights_df* показывает нам ежемесячную нагрузку в аэропорту с 1949 по 1960 год. Значения представляют собой количество пассажиров (в тысячах), прошедших через вход аэропорта.

# %%
sns.heatmap(flights)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\ACER\Downloads\3_visualize_data.ipynb Cell 43 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ACER/Downloads/3_visualize_data.ipynb#X60sZmlsZQ%3D%3D?line=0'>1</a> sns.heatmap(flights)
#       <a href='vscode-notebook-cell:/c%3A/Users/ACER/Downloads/3_visualize_data.ipynb#X60sZmlsZQ%3D%3D?line=1'>2</a> plt.show()
#
# NameError: name 'flights' is not defined

# %% [markdown]
# Чем светлее цвет, тем выше пешеходная заходка в аэропорту. Глядя на график, мы можем сделать вывод, что:
#
# - Самые высокие значения в июле и августе.
# - Количество пешеходов растет с каждым годом.
# - Любой месяц в году будет иметь более высокую проходимость по сравнению с предыдущими годами.

# %%
sns.heatmap(flights, fmt = 'd', annot = True, cmap = 'Blues')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Валерия Савина\Downloads\3_visualize_data.ipynb Ячейка 45 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/%D0%92%D0%B0%D0%BB%D0%B5%D1%80%D0%B8%D1%8F%20%D0%A1%D0%B0%D0%B2%D0%B8%D0%BD%D0%B0/Downloads/3_visualize_data.ipynb#X62sZmlsZQ%3D%3D?line=0'>1</a> sns.heatmap(flights, fmt = 'd', annot = True, cmap = 'Blues')
#       <a href='vscode-notebook-cell:/c%3A/Users/%D0%92%D0%B0%D0%BB%D0%B5%D1%80%D0%B8%D1%8F%20%D0%A1%D0%B0%D0%B2%D0%B8%D0%BD%D0%B0/Downloads/3_visualize_data.ipynb#X62sZmlsZQ%3D%3D?line=1'>2</a> plt.show()
#
# NameError: name 'flights' is not defined

# %% [markdown]
# ## Анализ данных на примере датасета Titanic

# %%
# Настройки визуализации
sns.set_style(style='white') 
sns.set(rc={
    'figure.figsize':(12,7), 
    'axes.facecolor': 'white',
    'axes.grid': True, 'grid.color': '.9',
    'axes.linewidth': 1.0,
    'grid.linestyle': u'-'},font_scale=1.5)
custom_colors = ["#3498db", "#95a5a6","#34495e", "#2ecc71", "#e74c3c"]
sns.set_palette(custom_colors)

# %% [markdown]
# Загрузим данные и посмотрим информацию о них.

# %%
import pandas as pd
df = pd.read_csv("titanic.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Survived                 887 non-null    int64
#  1   Pclass                   887 non-null    int64
#  2   Name                     887 non-null    object
#  3   Sex                      887 non-null    object
#  4   Age                      887 non-null    float64
#  5   Siblings/Spouses Aboard  887 non-null    int64
#  6   Parents/Children Aboard  887 non-null    int64
#  7   Fare                     887 non-null    float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.6+ KB

# %% [markdown]
# ### Анализируем класс (Pclass)

# %% [markdown]
# Посмотрим, какие классы есть в данных.

# %%
df.Pclass.unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %% [markdown]
# Команда **value_counts()** позволяется вывести количество для каждого уникального значения. Запомним ее.

# %%
df.Pclass.value_counts()
# Out:
# Pclass
# 3    487
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df.Pclass.value_counts().plot.pie().legend(labels=["Class 3","Class 1","Class 2"], loc='center right', bbox_to_anchor=(2.25, 0.5)).set_title("Распределение пассажиров по классам")

# %%
pclass_1_survivor_distribution = round((df[df.Pclass == 1].Survived == 1).value_counts()[1]/len(df[df.Pclass == 1]) * 100, 2)
pclass_2_survivor_distribution = round((df[df.Pclass == 2].Survived == 1).value_counts()[1]/len(df[df.Pclass == 2]) * 100, 2)
pclass_3_survivor_distribution = round((df[df.Pclass == 3].Survived == 1).value_counts()[1]/len(df[df.Pclass == 3]) * 100, 2)
pclass_perc_df = pd.DataFrame(
    { "Выжили":{"Class 1": pclass_1_survivor_distribution,"Class 2": pclass_2_survivor_distribution, "Class 3": pclass_3_survivor_distribution},  
     "Погибли":{"Class 1": 100-pclass_1_survivor_distribution,"Class 2": 100-pclass_2_survivor_distribution, "Class 3": 100-pclass_3_survivor_distribution}})
pclass_perc_df.plot.bar().set_title("Процент выживших по классам")
plt.show()
# Out:
# C:\Users\Валерия Савина\AppData\Local\Temp\ipykernel_17216\2147101652.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pclass_1_survivor_distribution = round((df[df.Pclass == 1].Survived == 1).value_counts()[1]/len(df[df.Pclass == 1]) * 100, 2)
# C:\Users\Валерия Савина\AppData\Local\Temp\ipykernel_17216\2147101652.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pclass_2_survivor_distribution = round((df[df.Pclass == 2].Survived == 1).value_counts()[1]/len(df[df.Pclass == 2]) * 100, 2)
# C:\Users\Валерия Савина\AppData\Local\Temp\ipykernel_17216\2147101652.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pclass_3_survivor_distribution = round((df[df.Pclass == 3].Survived == 1).value_counts()[1]/len(df[df.Pclass == 3]) * 100, 2)

# %% [markdown]
# *Пример анализа по показателю:*
#
# Показатель **Pclass** - класс, соотвествующий билету пассажира. Пассажиры могли выбрать из трех отдельных классов, а именно: класс 1, класс 2 и класс 3. Третий класс имел наибольшее количество пассажиров, затем класс 2 и класс 1. Количество пассажиров в третьем классе было больше, чем количество пассажиров в первом и втором классе вместе взятых. Вероятность выживания пассажира класса 1 была выше, чем пассажира класса 2 и класса 3.

# %% [markdown]
# ### Анализ показателя пол (Sex)

# %%
df.Sex.value_counts(normalize = True)
# Out:
# Sex
# male      0.645998
# female    0.354002
# Name: proportion, dtype: float64

# %% [markdown]
# Построим **barplot** процент женщин и мужчин на Титанике.

# %%
(df.Sex.value_counts(normalize = True) * 100).plot.bar()
plt.show()

# %% [markdown]
# Посмотрим процент выживших среди мужчин и женщин.

# %%
df[df.Sex == 'male'].Survived == 1
# Out:
# 0      False
# 4      False
# 5      False
# 6      False
# 7      False
#        ...
# 879    False
# 880    False
# 882    False
# 885     True
# 886    False
# Name: Survived, Length: 573, dtype: bool

# %%
(df[df.Sex == 'male'].Survived == 1).value_counts()
# Out:
# Survived
# False    464
# True     109
# Name: count, dtype: int64

# %%
round((df[df.Sex == 'male'].Survived == 1).value_counts()[1]/len(df.Sex)*100,2)
# Out:
# C:\Users\Валерия Савина\AppData\Local\Temp\ipykernel_5144\1894508938.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   round((df[df.Sex == 'male'].Survived == 1).value_counts()[1]/len(df.Sex)*100,2)
# 12.29

# %%
male_pr = round((df[df.Sex == 'male'].Survived == 1).value_counts()[1]/len(df.Sex) * 100, 2)
female_pr = round((df[df.Sex == 'female'].Survived == 1).value_counts()[1]/len(df.Sex) * 100, 2)
sex_perc_df = pd.DataFrame(
    { "Процент выживших":{"мужчины": male_pr,"женщины": female_pr},  "Погибшие":{"мужчины": 100-male_pr,"женщины": 100-female_pr}})
sex_perc_df.plot.barh().set_title("Процент выживших в разрезе м/ж")
plt.show()
# Out:
# C:\Users\Валерия Савина\AppData\Local\Temp\ipykernel_5144\3979448701.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   male_pr = round((df[df.Sex == 'male'].Survived == 1).value_counts()[1]/len(df.Sex) * 100, 2)
# C:\Users\Валерия Савина\AppData\Local\Temp\ipykernel_5144\3979448701.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   female_pr = round((df[df.Sex == 'female'].Survived == 1).value_counts()[1]/len(df.Sex) * 100, 2)

# %% [markdown]
# *Пример анализа:*
#
# Примерно 65% пассажиров составляли мужчины, а остальные 35% — женщины. Тем не менее, процент выживших женщин был выше, чем число выживших мужчин. Более 80% мужчин умерли, в сравнении с примерно 70% женщинами.

# %% [markdown]
# ### Анализируем возраст (Age)

# %%
min(df['Age'])
# Out:
# 0.42

# %%
max(df['Age'])
# Out:
# 80.0

# %% [markdown]
# Зададим интервалы и сгруппируем данные в эти интервалы.

# %%
df['Age_Range'] = pd.cut(df.Age, [0, 10, 20, 30, 40, 50, 60,70,80])
sns.countplot(x = "Age_Range", hue = "Survived", data = df, palette=["C1", "C0"]).legend(labels = ["Погибли", "Выжили"])
plt.show()

# %%
sns.distplot(df['Age'].dropna(),color='darkgreen',bins=30)
plt.show()
# Out:
# C:\Users\Валерия Савина\AppData\Local\Temp\ipykernel_17216\2470891357.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'].dropna(),color='darkgreen',bins=30)

# %% [markdown]
# Самому молодому путешественнику на борту было около двух месяцев, а самому старшему — 80 лет. Средний возраст пассажиров на борту был чуть менее 30 лет. Большая часть детей в возрасте до 10 лет выжила. В любой другой возрастной группе число жертв было выше, чем число выживших. Более 140 человек в возрастной группе 20-30 лет погибли в сравнении с примерно 80 выжившими того же возраста.

# %% [markdown]
# ### Самостоятельно анализируем стоимость тарифа (Fare) (5 баллов)

# %% [markdown]
# Схема анализа:
#
# 1) посмотреть с помощью value_counts() какие есть тарифы
#
# 2) возможно объединить тарифы в категории (например, Дешевые, Средние, Выше Среднего, Высокие) и создать новую переменную. Подсказка для разделения функция describe
#
# 3) визуализировать график и ответить на вопрос: "Как стоимость тарифа влияет на вероятность выживания?"

# %%
# решение 
df['Fare'].describe()
# Out:
# count    887.00000
# mean      32.30542
# std       49.78204
# min        0.00000
# 25%        7.92500
# 50%       14.45420
# 75%       31.13750
# max      512.32920
# Name: Fare, dtype: float64

# %%
#df.Fare.value_counts(normalize = True)
df['Fare_Category'] = pd.cut(df.Fare, [0, 8, 15, 32, 512],labels=['Дешевые', 'Средние', 'Выше Среднего', 'Высокие'])
sns.countplot(x = "Fare_Category", hue = "Survived", data = df).legend(['Погиб', 'Выжил'])
plt.show()

# %% [markdown]
# ### Самостоятельно анализируем Siblings/Spouses Aboard и Parents/Children Aboard (10 баллов)
#
# SibSp — это число братьев, сестер или супругов на борту у человека.
#
# Parents/Children Aboard - признак содержал количество родителей или детей, с которыми путешествовал каждый пассажир.

# %% [markdown]
# Вопросы для анализа:
# 1. Как влияет наличие семьи на выживаемость?
# 2. Какие путешествия чаще: в одиночку или с родственниками?
# 3. Насколько изменяются шансы на выживание в случае путешествия в одиночку?

# %%
# для удобства переименуем колонки
df.columns = ['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Age_Range', 'Fare_Category']
df.head()

#не очень понимаю, почему с последней компиляцией не заработал код, до этого график хорошо показывал :(
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Валерия Савина\Downloads\3_visualize_data.ipynb Ячейка 81 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/%D0%92%D0%B0%D0%BB%D0%B5%D1%80%D0%B8%D1%8F%20%D0%A1%D0%B0%D0%B2%D0%B8%D0%BD%D0%B0/Downloads/3_visualize_data.ipynb#Y143sZmlsZQ%3D%3D?line=0'>1</a> # для удобства переименуем колонки
# ----> <a href='vscode-notebook-cell:/c%3A/Users/%D0%92%D0%B0%D0%BB%D0%B5%D1%80%D0%B8%D1%8F%20%D0%A1%D0%B0%D0%B2%D0%B8%D0%BD%D0%B0/Downloads/3_visualize_data.ipynb#Y143sZmlsZQ%3D%3D?line=1'>2</a> df.columns = ['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Age_Range', 'Fare_Category']
#       <a href='vscode-notebook-cell:/c%3A/Users/%D0%92%D0%B0%D0%BB%D0%B5%D1%80%D0%B8%D1%8F%20%D0%A1%D0%B0%D0%B2%D0%B8%D0%BD%D0%B0/Downloads/3_visualize_data.ipynb#Y143sZmlsZQ%3D%3D?line=2'>3</a> df.head()
#
# File c:\Users\Валерия Савина\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6218, in NDFrame.__setattr__(self, name, value)
#    6216 try:
#    6217     object.__getattribute__(self, name)
# -> 6218     return object.__setattr__(self, name, value)
#    6219 except AttributeError:
#    6220     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File c:\Users\Валерия Савина\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:767, in NDFrame._set_axis(self, axis, labels)
#     762 """
#     763 This is called from the cython code when we set the `index` attribute
#     764 directly, e.g. `series.index = [1, 2, 3]`.
#     765 """
#     766 labels = ensure_index(labels)
# --> 767 self._mgr.set_axis(axis, labels)
#     768 self._clear_item_cache()
#
# File c:\Users\Валерия Савина\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:227, in BaseBlockManager.set_axis(self, axis, new_labels)
#     225 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     226     # Caller is responsible for ensuring we have an Index object.
# --> 227     self._validate_set_axis(axis, new_labels)
#     228     self.axes[axis] = new_labels
#
# File c:\Users\Валерия Савина\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\base.py:85, in DataManager._validate_set_axis(self, axis, new_labels)
#      82     pass
#      84 elif new_len != old_len:
# ---> 85     raise ValueError(
#      86         f"Length mismatch: Expected axis has {old_len} elements, new "
#      87         f"values have {new_len} elements"
#      88     )
#
# ValueError: Length mismatch: Expected axis has 9 elements, new values have 10 elements

# %%
# решение
df['Parch'] = pd.cut(df.Parch, bins = [0, 1, 2, 3, 4, 5], labels = ['Firth', 'Second', 'Third', 'Fourth', 'Fifth'])
plt.hist (color = "lightblue", ec = "red") 
sns.countplot(x = "Parch", hue = "Survived", data = df).legend(['Погибли', 'Выжили'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5144\3631450739.py in ?()
#       1 # решение
# ----> 2 df['Parch'] = pd.cut(df.Parch, bins = [0, 1, 2, 3, 4, 5], labels = ['Firth', 'Second', 'Third', 'Fourth', 'Fifth'])
#       3 plt.hist (color = "lightblue", ec = "red")
#       4 sns.countplot(x = "Parch", hue = "Survived", data = df).legend(['Погибли', 'Выжили'])
#       5 plt.show()
#
# c:\Users\Валерия Савина\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Parch'
